# %% [markdown]
# # NSU Audit Core - APK Builder
#
# Run this notebook to build your Android APK!

# %%
# Clone or upload the NSU Audit Mobile files
# If using Google Drive, mount it first:
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install buildozer
# !pip install kivy
# !pip install reportlab
# !pip install Pillow

# %%
# Install Android SDK dependencies
# !apt-get install -y 
    python3-pip 
    autoconf 
    libtool 
    pkg-config 
    zlib1g-dev 
    libncurses5-dev 
    libncursesw5-dev 
    libtinfo5 
    cmake 
    libffi-dev 
    libssl-dev

# %%
# Set working directory
# %cd /content

# Create project directory
# !mkdir -p nsuaudit
# %cd nsuaudit

# %%
# Copy main.py and buildozer.spec here
# Or upload your files to /content/nsuaudit/

# %%
# Build APK
# !buildozer android debug

# %%
# Download APK
from google.colab import files
import os

apk_path = '/content/nsuaudit/bin/'
if os.path.exists(apk_path):
    for f in os.listdir(apk_path):
        if f.endswith('.apk'):
            files.download(os.path.join(apk_path, f))
            print(f'Downloaded: {f}')
